# %% [markdown]
# # JupyterからPostgresへ接続するためのサンプル

# %%
# %load_ext sql
import os
import pandas as pd
import psycopg2
from sqlalchemy import create_engine
# Out:
# The sql extension is already loaded. To reload it, use:
#   %reload_ext sql

# %%
pgconfig = {
    'host': 'db',
    'port': os.environ['PG_PORT'],
    'database': os.environ['PG_DATABASE'],
    'user': os.environ['PG_USER'],
    'password': os.environ['PG_PASSWORD'],
}
dsl = 'postgresql://{user}:{password}@{host}:{port}/{database}'.format(**pgconfig)

# pd.read_sql用のコネクタ
conn = psycopg2.connect(**pgconfig)
# pd.to_sql用のcreate engine
engine = create_engine(dsl)
# MagicコマンドでSQLを書くための設定
# %sql $dsl
# Out:
# 'Connected: padawan@dsdojo_db'

# %%
df_prod = pd.read_sql(sql='select * from product', con=conn)

# %%
df_prod.head()
# Out:
#    product_cd product_name category_major_cd category_major_name  \
# 0  P040101001         焼うどん                04                  惣菜
# 1  P040101002       アジツケソバ                04                  惣菜
# 2  P040101003  ゴモクオニギリ３コイリ                04                  惣菜
# 3  P040101004         豆ごはん                04                  惣菜
# 4  P040101005  ワカメオニギリ３コイリ                04                  惣菜
#
#   category_medium_cd category_medium_name category_small_cd  \
# 0               0401                  御飯類            040101
# 1               0401                  御飯類            040101
# 2               0401                  御飯類            040101
# 3               0401                  御飯類            040101
# 4               0401                  御飯類            040101
#
#   category_small_name         jan_cd  unit_price  unit_cost
# 0                 弁当類  4958582008999         198        149
# 1                 弁当類  4515290000310         218        164
# ...

# %%
# データフレームをDBに書き出す場合
#df.to_sql('test', con=engine, if_exists='append', index=False)
#df.to_sql('test', con=engine, if_exists='replace', index=False)

# %%
# %%sql
# select * from product limit 10
# Out:
#  * postgresql://padawan:***@db:5432/dsdojo_db
# 10 rows affected.
# [('P040101001', '焼うどん', '04', '惣菜', '0401', '御飯類', '040101', '弁当類', '4958582008999', 198, 149),
#  ('P040101002', 'アジツケソバ', '04', '惣菜', '0401', '御飯類', '040101', '弁当類', '4515290000310', 218, 164),
#  ('P040101003', 'ゴモクオニギリ３コイリ', '04', '惣菜', '0401', '御飯類', '040101', '弁当類', '4958582010725', 230, 173),
#  ('P040101004', '豆ごはん', '04', '惣菜', '0401', '御飯類', '040101', '弁当類', '4958582009507', 248, 186),
#  ('P040101005', 'ワカメオニギリ３コイリ', '04', '惣菜', '0401', '御飯類', '040101', '弁当類', '4958582011715', 268, 201),
#  ('P040101006', 'ゴモクオニギリ', '04', '惣菜', '0401', '御飯類', '040101', '弁当類', '4958582000726', 298, 224),
#  ('P040101007', 'えんど屋  赤飯', '04', '惣菜', '0401', '御飯類', '040101', '弁当類', '4514369260686', 338, 254),
#  ('P040101008', 'カラアゲベントウ', '04', '惣菜', '0401', '御飯類', '040101', '弁当類', '4958582004205', 420, 315),
#  ('P040101009', 'カツ丼', '04', '惣菜', '0401', '御飯類', '040101', '弁当類', '4515118001062', 498, 374),
# ...
